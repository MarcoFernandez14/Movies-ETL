# %%
import json
import pandas as pd
import numpy as np

# %%
file_dir = 'C://Users/fernanm/Data_Bootcamp/Movies-ETL/movies_dataset'

# %%
kaggle_metadata = pd.read_csv(f'{file_dir}/movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}/ratings.csv')

# %%
# kaggle_metadata.head()
# kaggle_metadata.tail()
kaggle_metadata.sample(n=5)
# Out:
#        adult                              belongs_to_collection   budget  \
# 13058  False  {'id': 476063, 'name': 'Guinea Pig Collection'...        0
# 5409   False                                                NaN        0
# 23705  False                                                NaN  3000000
# 1444   False                                                NaN        0
# 6818   False                                                NaN        0
#
#                                                   genres homepage      id  \
# 13058                     [{'id': 27, 'name': 'Horror'}]      NaN   36073
# 5409   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...      NaN   46878
# 23705  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN  169298
# 1444   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   12793
# 6818   [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...      NaN   24203
#
#          imdb_id original_language original_title  \
# 13058  tt0161635                ja   ギニーピッグ2 血肉の華
# 5409   tt0078350                en      The Swarm
# 23705  tt2544734                en         Bullet
# 1444   tt0118586                en    All Over Me
# 6818   tt0050307                en       Desk Set
#
#                                                 overview  ... release_date  \
# 13058  A woman walking home late at night is attacked...  ...   1985-10-07
# 5409   Scientist Dr. Bradford Crane and army general ...  ...   1978-07-14
# 23705  Danny Trejo plays 'Bullet' a tough cop who tak...  ...   2014-02-25
# 1444   Claude and Ellen are best friends who live in ...  ...   1997-02-15
# 6818   Two extremely strong personalities clash over ...  ...   1957-08-02
#
#       revenue runtime                                   spoken_languages  \
# 13058     0.0    42.0               [{'iso_639_1': 'ja', 'name': '日本語'}]
# 5409      0.0   116.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 23705     0.0    87.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 1444      0.0    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 6818      0.0   103.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 13058  Released                                                NaN
# 5409   Released  Monsters by the millions - and they're all for...
# 23705  Released          This time they messed with the wrong guy!
# 1444   Released                                                NaN
# 6818   Released      Make the office a wonderful place to love in!
#
#                                          title  video vote_average vote_count
# 13058  Guinea Pig 2: Flower of Flesh and Blood  False          4.8       31.0
# 5409                                 The Swarm  False          5.4       50.0
# 23705                                   Bullet  False          4.2       35.0
# 1444                               All Over Me  False          5.9       15.0
# 6818                                  Desk Set  False          6.9       28.0
#
# [5 rows x 24 columns]

# %%
# ratings.head()
# ratings.tail()
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 802065      8258      223     5.0  1228996592
# 24543141  255105    77561     3.0  1444699336
# 8837728    91130     1580     3.5  1283950978
# 24276747  252133     1047     3.0   855175761
# 1506536    15484     2335     4.0   993962777
